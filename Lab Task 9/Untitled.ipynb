# %%
import os

# %%
import zipfile

# %%
from IPython.display import display, Image

# %%
from PIL import Image as PILImage

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# # Function to unzip the folder

# %%
directory_to_extract_to = 'extracted_images'

# %% [markdown]
# # Extract the zip file

# %%
with zipfile.ZipFile('Image.zip', 'r') as zip_ref:
    zip_ref.extractall(directory_to_extract_to)

# %% [markdown]
# # Unzip the folder

# %%
extraction_folder = 'image'  # Define your folder name or path
if not os.path.exists(extraction_folder):
    os.makedirs(extraction_folder)

print(f"Folder '{extraction_folder}' has been created.")
# Out:
# Folder 'image' has been created.

# %%
def unzip_folder(zip_file_path, extraction_folder):
    # Code to unzip the folder
    pass

unzip_folder("Image.zip", "image")

# %% [markdown]
# # Display the images

# %%
extracted_folder = 'extracted_images'

# %% [markdown]
# # Display each image

# %%
from PIL import Image
import os

def unzip_folder(zip_file_path, extraction_folder):
    # Code to unzip the folder
    pass

unzip_folder("my_zip_file.zip", "my_extraction_folder")

for file_name in os.listdir(extracted_folder):
    if file_name.lower().endswith(('png', 'jpg', 'jpeg', 'bmp', 'gif')):
        image_path = os.path.join(extracted_folder, file_name)
        img = Image.open(image_path)  # Corrected line
        plt.imshow(img)
        plt.axis('off')  # Hide axes

# %%
# Convert image to grey image

# %%
import os
import zipfile
from PIL import Image
import matplotlib.pyplot as plt

def unzip_and_process_images(zip_file_path, extract_to_folder):
    # Check if the zip file exists
    if not os.path.exists(zip_file_path):
        print(f"Error: The file {zip_file_path} does not exist.")
        return

    # Unzip the folder
    with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
        zip_ref.extractall(extract_to_folder)

    # Get list of all image files in the extracted folder
    image_files = [
        os.path.join(extract_to_folder, file)
        for file in os.listdir(extract_to_folder)
        if file.lower().endswith(('png', 'jpg', 'jpeg', 'bmp', 'gif'))
    ]

    # Check if any images are found
    if not image_files:
        print("No images found in the extracted folder.")
        return

    # Process each image
    for image_file in image_files:
        process_image(image_file)

def process_image(file_path):
    try:
        # Open the image
        img = Image.open(file_path)

        # Convert to grayscale
        grayscale_img = img.convert('L')
        
        # Simulate NIR (for demonstration purposes, using the red channel as a proxy)
        nir_img = img.split()[0]  # Use the red channel as a basic NIR simulation

        # Display the original, grayscale, and simulated NIR images
        plt.figure(figsize=(15, 5))

        plt.subplot(1, 3, 1)
        plt.imshow(img)
        plt.axis('off')
        plt.title('Original Image')

        plt.subplot(1, 3, 2)
        plt.imshow(grayscale_img, cmap='gray')
        plt.axis('off')
        plt.title('Grayscale Image')

        plt.subplot(1, 3, 3)
        plt.imshow(nir_img, cmap='gray')
        plt.axis('off')
        plt.title('Simulated NIR Image')

        plt.show()

    except Exception as e:
        print(f"Error processing the image {file_path}: {e}")

# Example usage
# Replace 'images.zip' with the path to your zip file
# Replace 'extracted_images' with the folder where you want to extract images
zip_file_path = 'images.zip'
extract_to_folder = 'extracted_images'

if not os.path.exists(extract_to_folder):
    os.makedirs(extract_to_folder)

unzip_and_process_images(zip_file_path, extract_to_folder)

# %%
# convert image that show difference between grey scale and NIR

# %%
# Process each image

# %%
image_files = ['anime.jfif', 'girl.jfif', 'image.jpg']

for image_file in image_files:
    process_image(image_file)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 4
#       1 image_files = ['anime.jfif', 'girl.jfif', 'image.jpg']
#       3 for image_file in image_files:
# ----> 4     process_image(image_file)
#
# NameError: name 'process_image' is not defined

# %%
    # Process each image
    for image_file in image_files:
        process_image(image_file)

def process_image(file_path):
    try:
        # Open the image
        img = Image.open(file_path)

        # Convert to grayscale
        grayscale_img = img.convert('L')
        
        # Simulate NIR (for demonstration purposes, using the red channel as a proxy)
        nir_img = img.split()[0]  # Use the red channel as a basic NIR simulation

        # Display the original, grayscale, and simulated NIR images
        plt.figure(figsize=(15, 5))

        plt.subplot(1, 3, 1)
        plt.imshow(img)
        plt.axis('off')
        plt.title('Original Image')

        plt.subplot(1, 3, 2)
        plt.imshow(grayscale_img, cmap='gray')
        plt.axis('off')
        plt.title('Grayscale Image')

        plt.subplot(1, 3, 3)
        plt.imshow(nir_img, cmap='gray')
        plt.axis('off')
        plt.title('Simulated NIR Image')

        plt.show()

    except Exception as e:
        print(f"Error processing the image {file_path}: {e}")

# Example usage
# Replace 'images.zip' with the path to your zip file
# Replace 'extracted_images' with the folder where you want to extract images
zip_file_path = 'images.zip'
extract_to_folder = 'extracted_images'

if not os.path.exists(extract_to_folder):
    os.makedirs(extract_to_folder)

unzip_and_process_images(zip_file_path, extract_to_folder)

# %%
# Apply masking on grey scale image
# Highlight defect
